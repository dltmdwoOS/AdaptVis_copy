# %%
# !bash oracle_research.sh

# %%
# !python research.py --results-path "output/results_Controlled_Images_A_adapt_vis_for_oracle_research_1.0_0.5_1.5_0.4_True.json" --save-prefix "output_backup/analysis_Controlled_Images_A_True"
