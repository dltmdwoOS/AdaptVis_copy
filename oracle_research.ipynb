# %%
# !bash oracle_research.sh
# Out:
# /venv/venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100%|█████████████████████████████| 950/950 [00:00<00:00, 12.8MB/s]
# model.safetensors.index.json: 70.1kB [00:00, 186MB/s]
# ...
# model-00001-of-00003.safetensors:   0%|             | 0.00/4.99G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   1%|     | 41.9M/4.99G [00:00<00:14, 340MB/s]
# model-00001-of-00003.safetensors:   2%|     | 83.9M/4.99G [00:00<00:13, 354MB/s]
# model-00001-of-00003.safetensors:   3%|▏     | 136M/4.99G [00:00<00:12, 398MB/s]
# model-00001-of-00003.safetensors:   4%|▏     | 189M/4.99G [00:00<00:11, 421MB/s]
# model-00001-of-00003.safetensors:   5%|▎     | 241M/4.99G [00:00<00:10, 434MB/s]
# ...

# %%
# !python research.py --results-path "output/results_Controlled_Images_A_adapt_vis_for_oracle_research_1.0_0.5_1.5_0.4_True.json" --save-prefix "output/analysis_Controlled_Images_A_True"
# Out:
# === Global Baseline ===
# Baseline Weight: 1.0
# Baseline Accuracy: 0.6030
#
# ===== Weight Pair: low=0.5, high=1.2 =====
# Oracle Accuracy for this pair: 0.9273
# [uncertainty_prob] Best Acc: 0.8667 | Best Th: 0.4070 | Gain over Baseline(1.0): 26.36%p
# [uncertainty_entropy] Best Acc: 0.8636 | Best Th: 0.9015 | Gain over Baseline(1.0): 26.06%p
# [uncertainty_jsd] Best Acc: 0.8667 | Best Th: 0.0364 | Gain over Baseline(1.0): 26.36%p
# Saved plot to output/analysis_Controlled_Images_A_True_pair_0.5_1.2.png
#
# ===== Weight Pair: low=0.5, high=1.5 =====
# Oracle Accuracy for this pair: 0.9242
# [uncertainty_prob] Best Acc: 0.8667 | Best Th: 0.4070 | Gain over Baseline(1.0): 26.36%p
# [uncertainty_entropy] Best Acc: 0.8636 | Best Th: 0.9015 | Gain over Baseline(1.0): 26.06%p
# [uncertainty_jsd] Best Acc: 0.8667 | Best Th: 0.0364 | Gain over Baseline(1.0): 26.36%p
# Saved plot to output/analysis_Controlled_Images_A_True_pair_0.5_1.5.png
#
# ===== Weight Pair: low=0.5, high=2.0 =====
# ...
