# %%
print(1)
# Out:
# 1

# %%
# !bash var_uncertainties_var_weights.sh

# %%
# !python research.py --results-path "output/results_COCO_QA_one_obj_adapt_vis_var_uncertainties_var_weights_1.0_0.5_1.2_0.3_True.json" --save-prefix "output_backup/analysis_COCO_QA_one_obj_True"
# Out:
# === Global Baseline ===
# Baseline Weight: 1.0
# Baseline Accuracy: 0.5824
#
# ===== Weight Pair: low=0.5, high=1.2 =====
# Oracle Accuracy for this pair: 0.7188
# [uncertainty_prob] Best Acc: 0.5994 | Best Th: 0.2934 | Gain over Baseline(1.0): 1.70%p
# [uncertainty_entropy] Best Acc: 0.5938 | Best Th: 0.9897 | Gain over Baseline(1.0): 1.14%p
# [uncertainty_jsd] Best Acc: 0.5938 | Best Th: 0.0016 | Gain over Baseline(1.0): 1.14%p
# Saved plot to output_backup/analysis_COCO_QA_two_obj_True_pair_0.5_1.2.png
#
# ===== Weight Pair: low=0.5, high=1.5 =====
# Oracle Accuracy for this pair: 0.7131
# [uncertainty_prob] Best Acc: 0.5909 | Best Th: 0.2934 | Gain over Baseline(1.0): 0.85%p
# [uncertainty_entropy] Best Acc: 0.5909 | Best Th: 0.9897 | Gain over Baseline(1.0): 0.85%p
# [uncertainty_jsd] Best Acc: 0.5909 | Best Th: 0.0035 | Gain over Baseline(1.0): 0.85%p
# Saved plot to output_backup/analysis_COCO_QA_two_obj_True_pair_0.5_1.5.png
#
# ===== Weight Pair: low=0.5, high=2.0 =====
# ...
