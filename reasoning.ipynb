# %%
import pandas as pd
import json

r1_path = "output_backup/results_Controlled_Images_A_reasoning_1_1.0_1.0_False.json"
r2_path = "output_backup/results_Controlled_Images_A_reasoning_2_1.0_1.0_False.json"
r3_path = "output_backup/results_Controlled_Images_A_reasoning_3_1.0_1.0_False.json"

with open(r1_path, 'r') as f:
    r1_data = json.load(f)
    
with open(r2_path, 'r') as f:
    r2_data = json.load(f)
    
with open(r3_path, 'r') as f:
    r3_data = json.load(f)
    
r1_df = pd.DataFrame(r1_data)
r2_df = pd.DataFrame(r2_data)
r3_df = pd.DataFrame(r3_data)

# %%
r1_df
# Out:
#                                                Prompt Step1_1_to_2  \
# 0   \nUSER: Where is the wineglass in relat...       Bottom
# 1   \nUSER: Where is the glass in relation ...       Bottom
# 2   \nUSER: Where is the mug in relation to...       Bottom
# 3   \nUSER: Where is the hat in relation to...       Bottom
# 4   \nUSER: Where is the bottle in relation...         Left
# ..                                                ...          ...
# 77  \nUSER: Where are the sunglasses in rel...       Bottom
# 78  \nUSER: Where is the bowl in relation t...       Bottom
# 79  \nUSER: Where is the book in relation t...       Bottom
# 80  \nUSER: Where is the dragonfruit in rel...       Bottom
# 81  \nUSER: Where is the mug in relation to...       Bottom
#
#    Step1_2_to_1  Is_consistent Generation Golden  uncertainty
# 0        Bottom          False       Left     On         0.35
# 1        Bottom          False       Left     On         0.38
# 2        Bottom          False       Left     On         0.38
# 3        Bottom          False      Right  Right         0.50
# 4        Bottom          False       Left   Left         0.78
# ..          ...            ...        ...    ...          ...
# 77       Bottom          False       Left     On         0.47
# 78       Bottom          False       Left     On         0.37
# 79       Bottom          False       Left   Left         0.72
# 80       Bottom          False       Left     On         0.31
# 81       Bottom          False      Right  Right         0.54
#
# [82 rows x 7 columns]

# %%
df = r1_df
valid_labels = ['Left', 'Right', 'Under', 'On']

correct_df = df[df['Generation'] == df['Golden']].copy()
wrong_df = df[df['Generation'] != df['Golden']].copy()
correct_df.loc[~correct_df['Generation'].isin(valid_labels), 'Generation'] = 'Unknown'
wrong_df.loc[~wrong_df['Generation'].isin(valid_labels), 'Generation'] = 'Unknown'
target_index = valid_labels + ['Unknown']

correct_distribution = correct_df['Generation'].value_counts().reindex(target_index, fill_value=0)
wrong_distribution = wrong_df['Generation'].value_counts().reindex(target_index, fill_value=0)


print(f"Acc: {len(df[df['Generation'] == df['Golden']]) / len(df)}")
print('-'*30)
print("정답 케이스의 예측 분포:")
print(correct_distribution) 
print('-'*30)
print("오답 케이스의 예측 분포:")
print(wrong_distribution)
# Out:
# Acc: 0.6097560975609756
# ------------------------------
# 정답 케이스의 예측 분포:
# Generation
# Left       22
# Right      17
# Under      11
# On          0
# Unknown     0
# Name: count, dtype: int64
# ------------------------------
# 오답 케이스의 예측 분포:
# Generation
# Left       20
# Right       8
# Under       3
# On          0
# Unknown     1
# Name: count, dtype: int64

# %%
df = r2_df
valid_labels = ['Left', 'Right', 'Under', 'On']

correct_df = df[df['Generation'] == df['Golden']].copy()
wrong_df = df[df['Generation'] != df['Golden']].copy()
correct_df.loc[~correct_df['Generation'].isin(valid_labels), 'Generation'] = 'Unknown'
wrong_df.loc[~wrong_df['Generation'].isin(valid_labels), 'Generation'] = 'Unknown'
target_index = valid_labels + ['Unknown']

correct_distribution = correct_df['Generation'].value_counts().reindex(target_index, fill_value=0)
wrong_distribution = wrong_df['Generation'].value_counts().reindex(target_index, fill_value=0)


print(f"Acc: {len(df[df['Generation'] == df['Golden']]) / len(df)}")
print('-'*30)
print("정답 케이스의 예측 분포:")
print(correct_distribution) 
print('-'*30)
print("오답 케이스의 예측 분포:")
print(wrong_distribution)
# Out:
# Acc: 0.6219512195121951
# ------------------------------
# 정답 케이스의 예측 분포:
# Generation
# Left       22
# Right      17
# Under      11
# On          1
# Unknown     0
# Name: count, dtype: int64
# ------------------------------
# 오답 케이스의 예측 분포:
# Generation
# Left       20
# Right       8
# Under       3
# On          0
# Unknown     0
# Name: count, dtype: int64

# %%
df = r3_df
valid_labels = ['Left', 'Right', 'Under', 'On']

correct_df = df[df['Generation'] == df['Golden']].copy()
wrong_df = df[df['Generation'] != df['Golden']].copy()
correct_df.loc[~correct_df['Generation'].isin(valid_labels), 'Generation'] = 'Unknown'
wrong_df.loc[~wrong_df['Generation'].isin(valid_labels), 'Generation'] = 'Unknown'
target_index = valid_labels + ['Unknown']

correct_distribution = correct_df['Generation'].value_counts().reindex(target_index, fill_value=0)
wrong_distribution = wrong_df['Generation'].value_counts().reindex(target_index, fill_value=0)


print(f"Acc: {len(df[df['Generation'] == df['Golden']]) / len(df)}")
print('-'*30)
print("정답 케이스의 예측 분포:")
print(correct_distribution) 
print('-'*30)
print("오답 케이스의 예측 분포:")
print(wrong_distribution)
# Out:
# Acc: 0.5
# ------------------------------
# 정답 케이스의 예측 분포:
# Generation
# Left       22
# Right      16
# Under       3
# On          0
# Unknown     0
# Name: count, dtype: int64
# ------------------------------
# 오답 케이스의 예측 분포:
# Generation
# Left       15
# Right      23
# Under       3
# On          0
# Unknown     0
# Name: count, dtype: int64

# %%
r3_df['Step1'].values
# Out:
# array(['The wineglass and the table have a left-right relationship in which the wineglass is placed next to the table.',
#        'The glass and the armchair have a left-right relationship in which one object is next to another. The glass is placed on the armchair, and the armchair is positioned next to the wall.',
#        'The mug and the armchair have a left-right relationship in which the mug is placed next to the armchair.',
#        'The hat and the chair have a left-right relationship in which one object is next to another. The hat is placed on the floor next to the wooden chair, which is positioned against the wall.',
#        'The bottle and the chair have a left-right relationship in which one object is next to another. The bottle is placed next to the chair, and they are both on the wooden floor.',
#        'The cap and the chair have a left-right relationship in which one object is next to another. The cap is placed on the floor next to the chair, while the chair is positioned against the wall.',
#        'The plant and the table have a left-right relationship in which the plant is placed next to the table.',
#        'The orange and the table have a 2. an on-under relationship in which one object is placed on or under another object. The orange is sitting on the table, which is placed on the floor.',
#        'The cap and the armchair have a left-right relationship in which one object is next to another. The red cap is placed next to the blue armchair, creating a visually interesting contrast between the two objects.',
#        'The oven mitt and the chair have a left-right relationship in which one object is next to another. The oven mitt is placed next to the wooden chair, creating a visually interesting scene.',
#        'The book and the armchair have a left-right relationship in which the book is placed on the armchair.',
#        'The scissors and the table have a left-right relationship in which one object is next to another. The scissors are placed on the table, indicating that they are positioned to the right of the table.',
#        'The banana and the chair have a left-right relationship in which one object is next to another. The banana is placed next to the wooden chair, creating a visually interesting scene.',
#        'The orange and the chair have a left-right relationship in which one object is next to another. The orange is placed next to the chair, and the chair is positioned next to the orange.',
#        'The can and the chair have a left-right relationship in which one object is next to another. The can is placed next to the chair, and the chair is positioned next to the can.',
#        'The scarf and the chair have a left-right relationship in which one object is next to another. The scarf is placed on the floor next to the chair, while the chair is positioned on the floor.',
#        'The plate and the chair have a left-right relationship in which one object is next to another. The plate is placed on the floor next to the wooden chair.',
#        'The water bottle and the chair have a left-right relationship in which one object is next to another.',
#        'The notepad and the armchair do not have a left-right relationship in which one object is next to another or an on-under relationship in which one object is placed on or under another object. Instead, the notepad is placed on the floor next to the armchair, which is positioned on the floor.',
#        'The tape and the armchair have a left-right relationship in which one object is next to another.',
#        'The book and the chair have a left-right relationship in which one object is next to another. The book is placed on the chair, and the chair is positioned next to the wall.',
#        'The plate and the table have a left-right relationship in which one object is next to another.',
#        'The painting and the chair have a left-right relationship in which one object is next to another. The chair is positioned next to the painting, creating a visually appealing arrangement.',
#        'The plant and the table have a left-right relationship in which one object is next to another. The plant is placed on the table, and the table is positioned next to the wall.',
#        'The bottle of mustard and the chair have a left-right relationship in which one object is next to another. The bottle of mustard is placed next to the chair, and they are both positioned on the wooden floor.',
#        'The pan and the armchair have a left-right relationship in which one object is next to another. The pan is placed next to the armchair, and the armchair is positioned next to the wall.',
#        'The beer bottle and the chair have a left-right relationship in which one object is next to another. The beer bottle is placed next to the wooden chair, creating a contrast between the two objects.',
#        'The pan and the armchair have a left-right relationship in which one object is next to another.',
#        'The orange and the chair have a left-right relationship in which one object is next to another. The orange is placed next to the chair, and the chair is positioned next to the orange.',
#        'The scarf and the armchair have a left-right relationship in which the scarf is placed on the floor next to the armchair.',
#        'The notepad and the armchair have a left-right relationship in which one object is next to another.',
#        'The banjo and the armchair have a left-right relationship in which the banjo is placed next to the armchair.',
#        'The cup and the chair have a left-right relationship in which one object is next to another. The cup is placed next to the chair, and they are both on the wooden floor.',
#        'The plate and the table have a left-right relationship in which one object is next to another. The plate is placed on the floor next to the table, which is positioned on the floor as well.',
#        'The wineglass and the armchair have a left-right relationship in which one object is next to another.',
#        'The bread and the armchair have a left-right relationship in which one object is next to another. The armchair is placed next to the bread, which is on the floor.',
#        'The bowl and the armchair have a left-right relationship in which one object is next to another. The bowl is placed next to the armchair, and they are both positioned on the wooden floor.',
#        'The toilet roll and the table have a left-right relationship in which one object is next to another. The toilet roll is placed on the table, and the table is positioned next to the wall.',
#        'The kettle and the table have a 2. an on-under relationship in which one object is placed on or under another object.',
#        'The wineglass and the armchair have a left-right relationship in which one object is next to another.',
#        'The banjo and the armchair have a left-right relationship in which the banjo is placed next to the armchair.',
#        'The glasses and the armchair have a left-right relationship in which one object is next to another.',
#        'The plate and the table have a left-right relationship in which one object is next to another. The plate is placed on the table, and the table is positioned next to the wall.',
#        'The pan and the chair have a left-right relationship in which one object is next to another. The pan is placed next to the chair, and the chair is positioned next to the pan.',
#        'The ball of yarn and the table have a 2. an on-under relationship in which one object is placed on or under another object.',
#        'The bottle and the table have a left-right relationship in which one object is next to another. The bottle is placed on the floor next to the table, and the table is positioned in front of the bottle.',
#        "The remote and the armchair have a left-right relationship in which one object is next to another. The remote is placed next to the armchair, indicating that it is likely used for operating the armchair's functions, such as adjusting the height, reclining, or adjusting the footrest.",
#        'The box and the chair have a left-right relationship in which one object is next to another. The chair is positioned next to the box, which is on the floor.',
#        'The sunglasses and the armchair have a left-right relationship in which one object is next to another.',
#        'The bottle of orange juice and the chair have a left-right relationship in which one object is next to another.',
#        'The bottle and the chair have a left-right relationship in which one object is next to another. The bottle is placed next to the chair, and the chair is positioned next to the bottle.',
#        'The sunglasses and the table have a left-right relationship in which one object is next to another.',
#        'The scarf and the armchair have a left-right relationship in which one object is next to another.',
#        'The wineglass and the table have a left-right relationship in which the wineglass is placed next to the table.',
#        'The oven mitt and the chair have a left-right relationship in which one object is next to another. The oven mitt is placed next to the wooden chair, which is positioned on the wooden floor.',
#        'The scissors and the table have a left-right relationship in which one object is next to another. The scissors are placed on the floor next to the table, while the table is standing on the floor.',
#        'The plant and the chair have a left-right relationship in which one object is next to another. The chair is placed next to the plant, and the plant is placed next to the chair.',
#        'The orange and the table have a 2. an on-under relationship in which one object is placed on or under another object. The orange is placed on the floor under the table.',
#        'The cup and the table have a left-right relationship in which one object is next to another. The cup is placed next to the table, and the table is positioned next to the wall.',
#        'The bottle of mustard and the chair have a left-right relationship in which one object is next to another. The bottle of mustard is placed next to the chair, not on or under it.',
#        'The bowl and the table have a left-right relationship in which the bowl is next to the table.',
#        'The beer bottle and the chair have a left-right relationship in which one object is next to another. The beer bottle is placed next to the chair, and they are both on the wooden floor.',
#        'The bottle of mustard and the chair have a left-right relationship in which one object is next to another.',
#        'The laptop and the chair have a left-right relationship in which the laptop is placed next to the chair.',
#        'The dog and the table have a 2. an on-under relationship in which one object is placed on or under another object. The dog is sitting on top of the table.',
#        'The scarf and the armchair have a left-right relationship in which one object is next to another. The scarf is placed on the armchair, indicating that it is positioned to the side of the chair.',
#        'The plant and the chair have a left-right relationship in which one object is next to another. The plant is placed on the chair, and the chair is positioned next to the wall.',
#        'The can and the armchair have a left-right relationship in which one object is next to another.',
#        'The remote and the armchair have a left-right relationship in which one object is next to another. The remote is placed next to the armchair, and they are both on the wooden floor.',
#        'The bowl and the table have a left-right relationship in which the bowl is placed next to the table.',
#        'The laptop and the armchair have a left-right relationship in which the laptop is placed on the armchair.',
#        'The bowl and the armchair have a left-right relationship in which one object is next to another.',
#        'The soda can and the armchair have a left-right relationship in which one object is next to another. The soda can is placed on the armchair, and the armchair is positioned next to the wall.',
#        'The orange and the table have a left-right relationship in which the orange is next to the table.',
#        'The photograph and the chair have a left-right relationship in which one object is next to another. The chair is placed next to the photograph, creating a visually interesting composition.',
#        'The beer bottle and the armchair have a left-right relationship in which one object is next to another.',
#        'The cap and the armchair have a left-right relationship in which one object is next to another. The red hat is placed on the floor next to the blue armchair.',
#        'The sunglasses and the armchair have a left-right relationship in which one object is next to another. The sunglasses are placed on the armchair, indicating that they are positioned to the side of the chair.',
#        'The bowl and the chair have a left-right relationship in which one object is next to another. The bowl is placed on the chair, and the chair is positioned next to the wall.',
#        'The book and the chair have a left-right relationship in which one object is next to another. The book is placed next to the chair, and the chair is positioned next to the book.',
#        'The dragonfruit and the table have a 2. an on-under relationship in which the dragonfruit is placed on or under the table.',
#        'The mug and the armchair have a left-right relationship in which one object is next to another. The mug is placed next to the armchair, and the armchair is positioned next to the wall.'],
#       dtype=object)
